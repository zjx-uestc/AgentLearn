# %%
from openai import OpenAI

# 剑指本地 Ollama 服务默认端口
client = OpenAI(
    base_url='http://localhost:11434/v1',
    api_key='ollama api key'  # 本地调用，秘钥可随意填
)

response = client.chat.completions.create(
    model="deepseek-r1:8b",
    messages=[
        {"role": "user", "content": "LLM是什么"}
    ]
)

print(response.choices[0].message.content)

# %%
from openai import OpenAI

# 剑指本地 Ollama 服务默认端口
client = OpenAI(
    base_url='http://localhost:11434/v1',
    api_key='ollama api key'  # 本地调用，秘钥可随意填
)

response = client.chat.completions.create(
    model="deepseek-r1:8b",
    messages=[
        {"role": "user", "content": "LLM是什么"}
    ],
    stream=True
)

for chunk in response:
    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end="", flush=True)
print()
# Out:
# 好的，我们来详细解释一下 LLM 是什么。
#
# **LLM 是 "Large Language Model" 的缩写，中文意思是“大规模语言模型”或简称“大语言模型”。**
#
# 简单来说，LLM 是一种非常先进的人工智能模型，其主要特点和能力包括：
#
# 1.  **大型规模：** 它的核心是一个拥有极其庞大参数量（参数通常以数十亿甚至上万亿计）的神经网络模型。
# 2.  **基于 Transformer 架构：** 绝大多数成熟的 LLM 都建立在“Transformer”模型架构之上，这是由 Google 在《Attention is All You Need》论文中提出的一种革命性的神经网络结构，特别擅长处理序列数据（如文本），并能有效捕捉词语之间的依赖关系。
# 3.  **海量数据训练：** 它们在极其庞大的数据集上进行训练，这些数据集通常包括互联网上公开的各种文本、对话、代码、百科全书词条等。
# 4.  **涌现能力：** 经过如此大规模的训练，LLM 会展现出一些在较小模型或传统 AI 系统中未预先编程、并未明确设计但突然“涌现”出来的能力。这是 LLM 最具革命性的特点之一：
#     *   **语言理解与生成：** 能够流畅地生成自然、语法正确、逻辑连贯的文本。
#     *   **知识问答：** 拥有广泛覆盖各领域知识，并能进行解释和回答问题的能力。
#     *   **文本创作：** 进行诗歌、新闻报道、故事、脚本、邮件等各种不同风格和类型的写作。
#     *   **代码生成与理解：** 能够编写、解释和调试各种编程语言的代码。
#     *   **内容总结、翻译、改写：** 能够对输入的文本进行各种形式的处理和转换。
#     *   **对话能力：** 能够在自然、多轮的对话中理解并回应用户的意图。
#     *   **少量提示学习：** 通过提供简单的例子（称为“提示”），LLM 可以学会生成特定类型的内容或执行复杂的、未在训练数据中精确覆盖的操作。
#
# ## LLM 相比之前的 AI 发展阶段
#
# LLM 是基于机器学习、特别是深度学习（尤其是 Transformer 架构）的重大突破。它可以被认为是继规则-based 程序、机器学习模型（SVM、决策树、神经网络）以及小的、特定任务的 Embedding 模型之后的一次飞跃。它代表了利用海量数据和计算资源训练具有强大通用性的 AI 的顶峰。
#
# ## 常见例子
#
# 开发出 LLM 的一些主要公司包括：
#
# *   OpenAI： GPT 系列 (GPT-3, GPT-4)
# *   Google： Gemini
# *   Meta： LLaMA， Llama 2
# *   Anthropic： Claude
#
# ## 总结
#
# LLM 是一种基于 Transformer 架构、在海量数据和算力上进行大规模训练的人工智能模型，它通过学习语言的规律，发展出惊人的语言理解和生成、知识获取和任务执行能力，从而能够执行多种多样的文本相关任务，并与人类用户进行复杂对话。它是当前人工智能领域，特别是文本生成和处理方面的核心驱动力。
